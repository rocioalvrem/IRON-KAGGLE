# %%
import pandas as pd

# %%
data = pd.read_csv('sales.csv')

# %%
data

# date -> 0-12 months, 0-3 years, drop unnamed.
# Out:
#         Unnamed: 0  store_ID  day_of_week        date  nb_customers_on_day  \
# 0           425390       366            4  2013-04-18                  517
# 1           291687       394            6  2015-04-11                  694
# 2           411278       807            4  2013-08-29                  970
# 3           664714       802            2  2013-05-28                  473
# 4           540835       726            4  2013-10-10                 1068
# ...            ...       ...          ...         ...                  ...
# 640835      359783       409            6  2013-10-26                  483
# 640836      152315        97            1  2014-04-14                  987
# 640837      117952       987            1  2014-07-07                  925
# 640838      435829      1084            4  2014-06-12                  725
# 640839      305711       695            7  2015-05-03                    0
#
#         open  promotion state_holiday  school_holiday  sales
# ...

# %%
# Sales -> dependant variable
# 
data.columns
# Out:
# Index(['Unnamed: 0', 'store_ID', 'day_of_week', 'date', 'nb_customers_on_day',
#        'open', 'promotion', 'state_holiday', 'school_holiday', 'sales'],
#       dtype='object')

# %%
data['date'] = pd.to_datetime(data['date'])
data['year'] = pd.to_datetime(data['date']).dt.year
data['month'] = pd.to_datetime(data['date']).dt.month
data
data.groupby(['open','state_holiday','school_holiday', 'day_of_week'])['index'].agg(['count'])
# Out:
#          index  store_ID  day_of_week       date  nb_customers_on_day  open  \
# 0       425390       366            4 2013-04-18                  517     1
# 1       291687       394            6 2015-04-11                  694     1
# 2       411278       807            4 2013-08-29                  970     1
# 3       664714       802            2 2013-05-28                  473     1
# 4       540835       726            4 2013-10-10                 1068     1
# ...        ...       ...          ...        ...                  ...   ...
# 640835  359783       409            6 2013-10-26                  483     1
# 640836  152315        97            1 2014-04-14                  987     1
# 640837  117952       987            1 2014-07-07                  925     1
# 640838  435829      1084            4 2014-06-12                  725     1
# 640839  305711       695            7 2015-05-03                    0     0
#
# ...

# %%
data['year'].unique()
data['state_holiday'] = data['state_holiday'].apply(lambda x: 1 if x in ['a', 'b', 'c'] else 0)
data['state_holiday'].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
# Assuming 'data' is your DataFrame containing the relevant columns

# Extracting predictor and target variables
x = data[['day_of_week', 'nb_customers_on_day', 'open', 'promotion', 'state_holiday', 'school_holiday','month']]
y = data[['sales']]

# Initializing and fitting the model
model = LinearRegression()
result = model.fit(x, y)

# Printing intercept and coefficients
print("Intercept:", result.intercept_)
print("Coefficients:", result.coef_)

# Calculating the regression line
regression_line = result.predict(x)

# Plotting
#plt.plot(y, regression_line, c='orange')
#plt.scatter(y, x)  # You might want to specify which column of 'x' to scatter against 'y'
#plt.xlabel('Sales')
#plt.ylabel('Predicted Sales')
#plt.show()

y_pred = model.predict(x)
r_squared = r2_score(y, y_pred)
print(r_squared)

# Your response here. 
import statsmodels.api as sm
# Agregar una constante al predictor (intercepto)
X = sm.add_constant(data[['day_of_week', 'nb_customers_on_day', 'open', 'promotion', 'state_holiday', 'school_holiday','month']])

# Ajustar el modelo de regresión lineal múltiple
model = sm.OLS(data['sales'], X).fit()

# Obtener un resumen completo
summary = model.summary()
print(summary)
# p-valores inferiores a 0.05, Adj. R-squared cercano a 1. Modelo robusto
# Out:
# Intercept: [385.91304792]
# Coefficients: [[ -77.08210791    6.05009538 1498.6175463  1286.78399373 -766.43467151
#     40.81163199   25.4357878 ]]
# 0.8534733273601581
#                             OLS Regression Results
# ...
# Dep. Variable:                  sales   R-squared:                       0.853
# Model:                            OLS   Adj. R-squared:                  0.853
# Method:                 Least Squares   F-statistic:                 5.332e+05
# Date:                Sat, 17 Feb 2024   Prob (F-statistic):               0.00
# Time:                        14:43:53   Log-Likelihood:            -5.5848e+06
# No. Observations:              640840   AIC:                         1.117e+07
# Df Residuals:                  640832   BIC:                         1.117e+07
# Df Model:                           7
# Covariance Type:            nonrobust
# ...
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ...

# %%
# Extracting predictor and target variables
x = data[['day_of_week', 'nb_customers_on_day', 'open', 'promotion', 'state_holiday', 'school_holiday','month']]
y = data[['sales']]

# Initializing and fitting the model
model = LinearRegression()
result = model.fit(x, y)

# Printing intercept and coefficients
print("Intercept:", result.intercept_)
print("Coefficients:", result.coef_)

# Calculating the regression line
regression_line = result.predict(x)

# Plotting
#plt.plot(y, regression_line, c='orange')
#plt.scatter(y, x)  # You might want to specify which column of 'x' to scatter against 'y'
#plt.xlabel('Sales')
#plt.ylabel('Predicted Sales')
#plt.show()

y_pred = model.predict(x)
r_squared = r2_score(y, y_pred)
print(r_squared)

# Your response here. 
import statsmodels.api as sm
# Agregar una constante al predictor (intercepto)
X = sm.add_constant(data[['day_of_week', 'nb_customers_on_day', 'open', 'promotion', 'state_holiday', 'school_holiday','month']])

# Ajustar el modelo de regresión lineal múltiple
model = sm.OLS(data['sales'], X).fit()

# Obtener un resumen completo
summary = model.summary()
print(summary)
# p-valores inferiores a 0.05, Adj. R-squared cercano a 1. Modelo robusto
# Out:
# Intercept: [385.91304792]
# Coefficients: [[ -77.08210791    6.05009538 1498.6175463  1286.78399373 -766.43467151
#     40.81163199   25.4357878 ]]
# 0.8534733273601581
#                             OLS Regression Results
# ...
# Dep. Variable:                  sales   R-squared:                       0.853
# Model:                            OLS   Adj. R-squared:                  0.853
# Method:                 Least Squares   F-statistic:                 5.332e+05
# Date:                Sat, 17 Feb 2024   Prob (F-statistic):               0.00
# Time:                        14:45:30   Log-Likelihood:            -5.5848e+06
# No. Observations:              640840   AIC:                         1.117e+07
# Df Residuals:                  640832   BIC:                         1.117e+07
# Df Model:                           7
# Covariance Type:            nonrobust
# ...
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ...

# %%
# Extracting predictor and target variables
x = data[['nb_customers_on_day','open','promotion']]
y = data[['sales']]

# Initializing and fitting the model
model = LinearRegression()
result = model.fit(x, y)

# Printing intercept and coefficients
print("Intercept:", result.intercept_)
print("Coefficients:", result.coef_)

# Calculating the regression line
regression_line = result.predict(x)

# Plotting
#plt.plot(y, regression_line, c='orange')
#plt.scatter(y, x)  # You might want to specify which column of 'x' to scatter against 'y'
#plt.xlabel('Sales')
#plt.ylabel('Predicted Sales')
#plt.show()

y_pred = model.predict(x)
r_squared = r2_score(y, y_pred)
print(r_squared)

# Your response here. 
import statsmodels.api as sm
# Agregar una constante al predictor (intercepto)
X = sm.add_constant(data[['nb_customers_on_day','open','promotion']])

# Ajustar el modelo de regresión lineal múltiple
model = sm.OLS(data['sales'], X).fit()

# Obtener un resumen completo
summary = model.summary()
print(summary)
# p-valores inferiores a 0.05, Adj. R-squared cercano a 1. Modelo robusto
# Out:
# Intercept: [-86.61390605]
# Coefficients: [[   6.08078618 1810.66315387 1334.32498753]]
# 0.8515260822131901
#                             OLS Regression Results
# ...
# Dep. Variable:                  sales   R-squared:                       0.852
# Model:                            OLS   Adj. R-squared:                  0.852
# Method:                 Least Squares   F-statistic:                 1.225e+06
# Date:                Sat, 17 Feb 2024   Prob (F-statistic):               0.00
# Time:                        15:30:31   Log-Likelihood:            -5.5890e+06
# No. Observations:              640840   AIC:                         1.118e+07
# Df Residuals:                  640836   BIC:                         1.118e+07
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# ...

# %%
# Extracting predictor and target variables
x = data[['nb_customers_on_day','open','promotion','month']]
y = data[['sales']]

# Initializing and fitting the model
model = LinearRegression()
result = model.fit(x, y)

# Printing intercept and coefficients
print("Intercept:", result.intercept_)
print("Coefficients:", result.coef_)

# Calculating the regression line
regression_line = result.predict(x)

# Plotting
#plt.plot(y, regression_line, c='orange')
#plt.scatter(y, x)  # You might want to specify which column of 'x' to scatter against 'y'
#plt.xlabel('Sales')
#plt.ylabel('Predicted Sales')
#plt.show()

y_pred = model.predict(x)
r_squared = r2_score(y, y_pred)
print(r_squared)

# Your response here. 
import statsmodels.api as sm
# Agregar una constante al predictor (intercepto)
X = sm.add_constant(data[['nb_customers_on_day','open','promotion','month']])

# Ajustar el modelo de regresión lineal múltiple
model = sm.OLS(data['sales'], X).fit()

# Obtener un resumen completo
summary = model.summary()
print(summary)
# p-valores inferiores a 0.05, Adj. R-squared cercano a 1. Modelo robusto
# Out:
# Intercept: [-240.10864675]
# Coefficients: [[   6.06783063 1818.97467069 1338.5091418    26.20406614]]
# 0.8520367063020009
#                             OLS Regression Results
# ...
# Dep. Variable:                  sales   R-squared:                       0.852
# Model:                            OLS   Adj. R-squared:                  0.852
# Method:                 Least Squares   F-statistic:                 9.226e+05
# Date:                Sat, 17 Feb 2024   Prob (F-statistic):               0.00
# Time:                        15:30:53   Log-Likelihood:            -5.5879e+06
# No. Observations:              640840   AIC:                         1.118e+07
# Df Residuals:                  640835   BIC:                         1.118e+07
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ...

# %%
# Extracting predictor and target variables
x = data[['day_of_week', 'open', 'promotion']]
y = data[['sales']]

# Initializing and fitting the model
model = LinearRegression()
result = model.fit(x, y)

# Printing intercept and coefficients
print("Intercept:", result.intercept_)
print("Coefficients:", result.coef_)

# Calculating the regression line
regression_line = result.predict(x)

# Plotting
#plt.plot(y, regression_line, c='orange')
#plt.scatter(y, x)  # You might want to specify which column of 'x' to scatter against 'y'
#plt.xlabel('Sales')
#plt.ylabel('Predicted Sales')
#plt.show()

y_pred = model.predict(x)
r_squared = r2_score(y, y_pred)
print(r_squared)

# Your response here. 
import statsmodels.api as sm
# Agregar una constante al predictor (intercepto)
X = sm.add_constant(data[['day_of_week', 'open', 'promotion']])

# Ajustar el modelo de regresión lineal múltiple
model = sm.OLS(data['sales'], X).fit()

# Obtener un resumen completo
summary = model.summary()
print(summary)
# p-valores inferiores a 0.05, Adj. R-squared cercano a 1. Modelo robusto
# Out:
# Intercept: [561.1382476]
# Coefficients: [[-109.84634296 5861.54694842 2068.4558016 ]]
# 0.5318490897869192
#                             OLS Regression Results
# ...
# Dep. Variable:                  sales   R-squared:                       0.532
# Model:                            OLS   Adj. R-squared:                  0.532
# Method:                 Least Squares   F-statistic:                 2.427e+05
# Date:                Sat, 17 Feb 2024   Prob (F-statistic):               0.00
# Time:                        14:56:07   Log-Likelihood:            -5.9570e+06
# No. Observations:              640840   AIC:                         1.191e+07
# Df Residuals:                  640836   BIC:                         1.191e+07
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# ...

# %%
# Extracting predictor and target variables
x = data[data['open']==1][['day_of_week', 'nb_customers_on_day','promotion', 'state_holiday', 'school_holiday','month']]
y = data[data['open']==1][['sales']]

# Initializing and fitting the model
model = LinearRegression()
result = model.fit(x, y)

# Printing intercept and coefficients
print("Intercept:", result.intercept_)
print("Coefficients:", result.coef_)

# Calculating the regression line
regression_line = result.predict(x)

# Plotting
#plt.plot(y, regression_line, c='orange')
#plt.scatter(y, x)  # You might want to specify which column of 'x' to scatter against 'y'
#plt.xlabel('Sales')
#plt.ylabel('Predicted Sales')
#plt.show()

y_pred = model.predict(x)
r_squared = r2_score(y, y_pred)
print(r_squared)

# Your response here. 
import statsmodels.api as sm
# Agregar una constante al predictor (intercepto)
X = sm.add_constant(data[data['open']==1][['day_of_week', 'nb_customers_on_day', 'promotion', 'state_holiday', 'school_holiday','month']])

# Ajustar el modelo de regresión lineal múltiple
model = sm.OLS(data[data['open']==1][['sales']], X).fit()

# Obtener un resumen completo
summary = model.summary()
print(summary)
# p-valores inferiores a 0.05, Adj. R-squared cercano a 1. Modelo robusto
# Out:
# Intercept: [1829.00610424]
# Coefficients: [[  -71.65755097     6.0443372   1335.79397602 -1857.03539287
#      32.07712462    29.16374982]]
# 0.7302444319435542
#                             OLS Regression Results
# ...
# Dep. Variable:                  sales   R-squared:                       0.730
# Model:                            OLS   Adj. R-squared:                  0.730
# Method:                 Least Squares   F-statistic:                 2.400e+05
# Date:                Sat, 17 Feb 2024   Prob (F-statistic):               0.00
# Time:                        14:55:15   Log-Likelihood:            -4.6842e+06
# No. Observations:              532016   AIC:                         9.368e+06
# Df Residuals:                  532009   BIC:                         9.369e+06
# Df Model:                           6
# Covariance Type:            nonrobust
# ...
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ...

# %%
# Extracting predictor and target variables
x = data[data['open']==1][['day_of_week', 'nb_customers_on_day','promotion', 'state_holiday', 'school_holiday']]
y = data[data['open']==1][['sales']]

# Initializing and fitting the model
model = LinearRegression()
result = model.fit(x, y)

# Printing intercept and coefficients
print("Intercept:", result.intercept_)
print("Coefficients:", result.coef_)

# Calculating the regression line
regression_line = result.predict(x)

# Plotting
#plt.plot(y, regression_line, c='orange')
#plt.scatter(y, x)  # You might want to specify which column of 'x' to scatter against 'y'
#plt.xlabel('Sales')
#plt.ylabel('Predicted Sales')
#plt.show()

y_pred = model.predict(x)
r_squared = r2_score(y, y_pred)
print(r_squared)

# Your response here. 
import statsmodels.api as sm
# Agregar una constante al predictor (intercepto)
X = sm.add_constant(data[data['open']==1][['day_of_week', 'nb_customers_on_day','promotion', 'state_holiday', 'school_holiday']])

# Ajustar el modelo de regresión lineal múltiple
model = sm.OLS(data[data['open']==1][['sales']], X).fit()

# Obtener un resumen completo
summary = model.summary()
print(summary)
# p-valores inferiores a 0.05, Adj. R-squared cercano a 1. Modelo robusto
# Out:
# Intercept: [1986.38815268]
# Coefficients: [[  -71.89666645     6.05789956  1331.55327711 -1866.77636808
#      60.64458945]]
# 0.72928669789074
#                             OLS Regression Results
# ...
# Dep. Variable:                  sales   R-squared:                       0.729
# Model:                            OLS   Adj. R-squared:                  0.729
# Method:                 Least Squares   F-statistic:                 2.866e+05
# Date:                Sat, 17 Feb 2024   Prob (F-statistic):               0.00
# Time:                        14:54:31   Log-Likelihood:            -4.6852e+06
# No. Observations:              532016   AIC:                         9.370e+06
# Df Residuals:                  532010   BIC:                         9.370e+06
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ...

# %% [markdown]
# # KNN Model

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.25, random_state = 1)
from sklearn.preprocessing import MinMaxScaler
import numpy as np
scaler = MinMaxScaler()

scaler = scaler.fit(X_train)
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)
# create knn model
knnr = KNeighborsRegressor(n_neighbors = 3,weights='distance')

# Train the knn model
model = knnr.fit(X_train, y_train)
y_pred = knnr.predict(X_test)
y_pred
np.array(y_test)
# Predict and score the model
knnr.score(X_test, y_test)
# Out:
# 0.46796951783277535

# %% [markdown]
# # Lineal regression with test and train

# %%
# Extracting predictor and target variables
x = data[['nb_customers_on_day','open','promotion']]
y = data[['sales']]

# Initializing and fitting the model
model = LinearRegression()
result = model.fit(x, y)

# Printing intercept and coefficients
print("Intercept:", result.intercept_)
print("Coefficients:", result.coef_)

# Calculating the regression line
regression_line = result.predict(x)

# Plotting
#plt.plot(y, regression_line, c='orange')
#plt.scatter(y, x)  # You might want to specify which column of 'x' to scatter against 'y'
#plt.xlabel('Sales')
#plt.ylabel('Predicted Sales')
#plt.show()

y_pred = model.predict(x)
r_squared = r2_score(y, y_pred)
print(r_squared)

# Your response here. 
import statsmodels.api as sm
# Agregar una constante al predictor (intercepto)
X = sm.add_constant(data[['nb_customers_on_day','open','promotion']])

# Ajustar el modelo de regresión lineal múltiple
model = sm.OLS(data['sales'], X).fit()

# Obtener un resumen completo
summary = model.summary()
print(summary)
# p-valores inferiores a 0.05, Adj. R-squared cercano a 1. Modelo robusto

# Create linear regression
regr = LinearRegression()
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state = 1)
# Train the linear regression
model = regr.fit(X_train, y_train)

# Score the model
model.score(X_test, y_test)

model.predict(X_test)
np.array(y_test)

np.sqrt(((regr.predict(X_test)-np.array(y_test))**2).sum()/len(X_test))

model.coef_


#ridge tries to control the coefficients
from sklearn.linear_model import Ridge

# Create linear regression
regr = Ridge(alpha=1.0)

# Train the linear regression
model = regr.fit(X_train, y_train)

# Score the model
model.score(X_test, y_test)
# Out:
# Intercept: [-86.61390605]
# Coefficients: [[   6.08078618 1810.66315387 1334.32498753]]
# 0.8515260822131901
#                             OLS Regression Results
# ...
# Dep. Variable:                  sales   R-squared:                       0.852
# Model:                            OLS   Adj. R-squared:                  0.852
# Method:                 Least Squares   F-statistic:                 1.225e+06
# Date:                Sat, 17 Feb 2024   Prob (F-statistic):               0.00
# Time:                        15:32:40   Log-Likelihood:            -5.5890e+06
# No. Observations:              640840   AIC:                         1.118e+07
# Df Residuals:                  640836   BIC:                         1.118e+07
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# ...

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.25, random_state = 1)
from sklearn.preprocessing import MinMaxScaler
import numpy as np
scaler = MinMaxScaler()

scaler = scaler.fit(X_train)
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)
# create knn model
knnr = KNeighborsRegressor(n_neighbors = 3,weights='distance')

# Train the knn model
model = knnr.fit(X_train, y_train)
y_pred = knnr.predict(X_test)
y_pred
np.array(y_test)
# Predict and score the model
knnr.score(X_test, y_test)
# Out:
# 0.8205288613428635

# %%
y_pred = knnr.predict(X_test)
y_pred
# Out:
# array([[ 6314.66666667],
#        [11357.        ],
#        [    0.        ],
#        ...,
#        [ 8565.66666667],
#        [ 6422.33333333],
#        [ 8022.66666667]])

# %%
import pandas as pd
import pickle
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline


# Assuming x and y are your predictor and target variables respectively
x = data[[ 'nb_customers_on_day', 'open', 'promotion']]
y = data['sales']

# Initialize your model
model = LinearRegression()

# Train your model
model.fit(x, y)

# Make predictions
predictions = model.predict(x)

# Save the trained model
with open('model.pkl', 'wb') as file:
    pickle.dump(model, file)

# 3. Save Output to File
# Combine predictions with index and save to a CSV file
output_df = pd.DataFrame({'index': data.index, 'prediction': predictions})
output_df.to_csv('output.csv', index=False)

# 4. Save Model and Feature Engineering
# Save model and feature engineering steps (already done above)

# %%
test = pd.read_csv('validation_for students.csv')
x_test = test[[ 'nb_customers_on_day', 'open', 'promotion']]
x_test
# Out:
#        nb_customers_on_day  open  promotion
# 0                        0     0          0
# 1                        0     0          0
# 2                      657     1          1
# 3                      862     1          0
# 4                      591     1          1
# ...                    ...   ...        ...
# 71200                    0     0          0
# 71201                    0     0          0
# 71202                  648     1          0
# 71203                  626     1          1
# 71204                  828     1          1
#
# [71205 rows x 3 columns]

# %%
import pandas as pd
import pickle


with open('model.pkl', 'rb') as file:
    model = pickle.load(file)


new_data = pd.read_csv('validation_for students.csv')

x_new_data = new_data[['nb_customers_on_day', 'open', 'promotion']]


y_pred_new = model.predict(x_new_data)


y_pred_new
# Out:
# array([ -86.61390605,  -86.61390605, 7053.45075243, ..., 5664.39868933,
#        6864.946381  , 8093.26518838])

# %%
predictions_df = pd.DataFrame({'Index': new_data['index'], 'Prediction': y_pred_new})


predictions_df.to_csv('predictions_new_data.csv', index=False)

# %%
new_data
# Out:
#         index  store_ID  day_of_week        date  nb_customers_on_day  open  \
# 0      272371       415            7  01/03/2015                    0     0
# 1      558468        27            7  29/12/2013                    0     0
# 2       76950       404            3  19/03/2014                  657     1
# 3       77556       683            2  29/01/2013                  862     1
# 4      456344       920            3  19/03/2014                  591     1
# ...       ...       ...          ...         ...                  ...   ...
# 71200   59062       441            7  26/10/2014                    0     0
# 71201  687449       377            7  18/08/2013                    0     0
# 71202  207393        15            3  11/06/2014                  648     1
# 71203  233378       950            2  23/04/2013                  626     1
# 71204   85695       932            4  21/11/2013                  828     1
#
#        promotion state_holiday  school_holiday
# ...
